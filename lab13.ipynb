# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from textblob import TextBlob

plt.style.use('ggplot')

import nltk
import streamlit as st

# %%
## Reading the clean data
df=pd.read_csv('C:\\Users\\Hp\\Desktop\\Python-FinalProject\\spotify-cleaned_data.csv')

##Scaling down the size of reviews for MVP
df=df.head(500)
df.head()
# Out:
#     ID                                             Review  Rating  \
# 0  1.0  great music service audio high quality app eas...       5
# 1  2.0  please ignore previous negative rating app sup...       5
# 2  3.0  popup get best spotify experience android 12 a...       4
# 3  4.0                 really buggy terrible use recently       1
# 4  5.0  dear spotify get songs didnt put playlist shuf...       1
#
#    Total_thumbsup
# 0               2
# 1               1
# 2               0
# 3               1
# 4               1

# %% [markdown]
# ### Is there a Correlation between Rating and Thumbsup

# %%
# Calculate the correlation coefficient
correlation = df['Rating'].corr(df['Total_thumbsup'])

# Print the correlation coefficient
print(correlation)


# Create the plot
# Calculate the correlation coefficient
correlation = df['Rating'].corr(df['Total_thumbsup'])

# Create the Streamlit app
st.title('Correlation between Thumbsup and Rating')

# Display the correlation coefficient
st.write('Correlation coefficient:', correlation)

# Create the plot
fig, ax = plt.subplots()
ax.plot(df['Total_thumbsup'], df['Rating'], label='Relation between Rating and Thumbsup')

# Add labels and title
ax.set_xlabel('Total_thumbsup')
ax.set_ylabel('Rating')
ax.set_title('Line Graph')

# Add legend
ax.legend()

# Add the plot to the Streamlit app
st.pyplot(fig)
# Out:
# -0.08194228699490436
# 2023-11-20 20:22:31.615
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Hp\miniconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
subset_df = df.iloc[:10, :2]
st.dataframe(subset_df)
# Out:
# DeltaGenerator()

# %%
pip freeze >requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
